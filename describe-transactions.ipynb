# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/kaggle/input/dirty-iranian-transactions-dataset/trx-extra-10k.csv")

print(df.describe())
# Out:
#                 id        amount          fees      discount  balance_before  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000    1.000000e+04
# mean    5000.50000  2.496154e+06   3508.191100  15005.453100    5.960904e+06
# std     2886.89568  1.443942e+06   2024.139837   8690.563718    2.449145e+06
# min        1.00000  1.048100e+04      0.000000      3.000000    8.118800e+04
# 25%     2500.75000  1.248772e+06   1751.000000   7516.000000    4.197184e+06
# 50%     5000.50000  2.482238e+06   3518.000000  15058.000000    5.949281e+06
# 75%     7500.25000  3.754708e+06   5262.000000  22555.750000    7.753778e+06
# max    10000.00000  4.998515e+06   6999.000000  29998.000000    1.187947e+07
#
#          is_weekend
# count  10000.000000
# mean       0.494300
# std        0.499993
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
sb .boxplot(x=df["amount"])
plt.show()

# %%
numeric_df = df.select_dtypes(include=["number"])

corr = numeric_df.corr()
sb.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
print(df["city"].value_counts(normalize=True))
# Out:
# city
# Shiraz          0.0564
# Qazvin          0.0554
# Qom             0.0547
# Tehran          0.0542
# Sanandaj        0.0538
# Yazd            0.0537
# Kerman          0.0535
# Hamadan         0.0533
# Mashhad         0.0532
# Urmia           0.0529
# Arak            0.0528
# Karaj           0.0526
# Kashan          0.0520
# Kermanshah      0.0519
# Isfahan         0.0516
# Rasht           0.0515
# Ahvaz           0.0507
# Tabriz          0.0498
# Bandar Abbas    0.0460
# Name: proportion, dtype: float64
